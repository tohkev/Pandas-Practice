# %%
#importing dependencies
import pandas as pd

# %%
#creating DataFrame from csv file
path = "Resources/EclipseBugs.csv"
bugs_df = pd.read_csv(path)
bugs_df.head()
# Out:
#    Bug\nID Product Component Assignee    Status Resolution  \
# 0     3638     JDT        UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT        UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ... Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                   3
# 1   Martin Aeschlimann        Eclipse  ...                   5
# 2   Martin Aeschlimann        Eclipse  ...                   3
# 3   Martin Aeschlimann        Eclipse  ...                  10
# 4   Martin Aeschlimann        Eclipse  ...                   5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
bugs_df.count()
# Out:
# Bug\nID                 10000
# Product                 10000
# Component               10000
# Assignee                10000
# Status                  10000
# Resolution              10000
# Summary                 10000
# Changed                 10000
# Assignee\nReal\nName    10000
# Classification          10000
# Hardware                10000
# Number of\nComments     10000
# Opened                  10000
# OS                      10000
# Priority                10000
# Reporter                10000
# Reporter\nReal\nName     9967
# Severity                10000
# Target\nMilestone       10000
# Version                 10000
# Votes                   10000
# dtype: int64

# %%
#fixing naming conventions of some columns
renamed_bugs_df = bugs_df.rename(columns={
    "Bug\nID":"Bug ID",
    "Assignee\nReal\nName":"Assignee Real Name",
    "Number of\nComments":"Number of Comments",
    "Reporter\nReal\nName": "Reporter Real Name",
    "Target\nMilestone":"Target Milestone"
})
renamed_bugs_df.columns
# Out:
# Index(['Bug ID', 'Product', 'Component', 'Assignee', 'Status', 'Resolution',
#        'Summary', 'Changed', 'Assignee Real Name', 'Classification',
#        'Hardware', 'Number of Comments', 'Opened', 'OS', 'Priority',
#        'Reporter', 'Reporter Real Name', 'Severity', 'Target Milestone',
#        'Version', 'Votes'],
#       dtype='object')

# %%
renamed_bugs_df.dtypes
# Out:
# Bug ID                 int64
# Product               object
# Component             object
# Assignee              object
# Status                object
# Resolution            object
# Summary               object
# Changed               object
# Assignee Real Name    object
# Classification        object
# Hardware              object
# Number of Comments     int64
# Opened                object
# OS                    object
# Priority              object
# Reporter              object
# Reporter Real Name    object
# Severity              object
# Target Milestone      object
# Version               object
# Votes                  int64
# dtype: object

# %%
#grouping by the assignee to show how many of each component was resolved
assignee_group = renamed_bugs_df.groupby("Assignee")
assignee_df = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_df.head()
# Out:
#                                 Component
# Assignee       Component
# Aaron_Ferguson UI                      10
# Adam_Schlegel  UI                       7
# ChrisAustin    User Assistance          3
# Claude_Knaus   UI                      31
#                Text                     7

# %%
#specifying the naming convention
assignee_df = assignee_df.rename(columns={"Component":"Component Bug Count"})
assignee_df.head()
# Out:
#                                 Component Bug Count
# Assignee       Component
# Aaron_Ferguson UI                                10
# Adam_Schlegel  UI                                 7
# ChrisAustin    User Assistance                    3
# Claude_Knaus   UI                                31
#                Text                               7

# %%
#calculating the percentage of bugs fixed based on total
total_bugs = len(bugs_df)
total_bugs
# Out:
# 10000

# %%
bugs_per_user = assignee_group["Assignee"].count()
bugs_per_user.head()
# Out:
# Assignee
# Aaron_Ferguson    10
# Adam_Schlegel      7
# ChrisAustin        3
# Claude_Knaus      38
# Curtis_Windatt     6
# Name: Assignee, dtype: int64

# %%
bug_percentage_df = pd.DataFrame(bugs_per_user/total_bugs*100)
bug_percentage_df.head()
# Out:
#                 Assignee
# Assignee
# Aaron_Ferguson      0.10
# Adam_Schlegel       0.07
# ChrisAustin         0.03
# Claude_Knaus        0.38
# Curtis_Windatt      0.06

# %%
bug_percentage_df = bug_percentage_df.rename(columns={"Assignee":"% of Bugs Assigned"})
bug_percentage_df.head()
# Out:
#                 % of Bugs Assigned
# Assignee
# Aaron_Ferguson                0.10
# Adam_Schlegel                 0.07
# ChrisAustin                   0.03
# Claude_Knaus                  0.38
# Curtis_Windatt                0.06

# %%
assignee_df.head()
# Out:
#                                 Component Bug Count
# Assignee       Component
# Aaron_Ferguson UI                                10
# Adam_Schlegel  UI                                 7
# ChrisAustin    User Assistance                    3
# Claude_Knaus   UI                                31
#                Text                               7

# %%
assignee_df = assignee_df.reset_index()
assignee_df.head()
# Out:
#          Assignee        Component  Component Bug Count
# 0  Aaron_Ferguson               UI                   10
# 1   Adam_Schlegel               UI                    7
# 2     ChrisAustin  User Assistance                    3
# 3    Claude_Knaus               UI                   31
# 4    Claude_Knaus             Text                    7

# %%
#merging % of bugs fixed into one DataFrame
merged_assignee_df = pd.merge(assignee_df, bug_percentage_df, on="Assignee")
merged_assignee_df.head()
# Out:
#          Assignee        Component  Component Bug Count  % of Bugs Assigned
# 0  Aaron_Ferguson               UI                   10                0.10
# 1   Adam_Schlegel               UI                    7                0.07
# 2     ChrisAustin  User Assistance                    3                0.03
# 3    Claude_Knaus               UI                   31                0.38
# 4    Claude_Knaus             Text                    7                0.38

# %%
renamed_bugs_df["Severity"].value_counts()
# Out:
# normal         6517
# major          1375
# enhancement     913
# critical        459
# minor           327
# trivial         300
# blocker         109
# Name: Severity, dtype: int64

# %%
assignee_severity_df = pd.DataFrame(assignee_group["Severity"].value_counts())
assignee_severity_df.head()
# Out:
#                          Severity
# Assignee       Severity
# Aaron_Ferguson normal          10
# Adam_Schlegel  normal           5
#                major            2
# ChrisAustin    normal           2
#                minor            1

# %%
assignee_severity_df = assignee_severity_df.rename(columns={"Severity":"Count of Bugs"})
assignee_severity_df
# Out:
#                           Count of Bugs
# Assignee        Severity
# Aaron_Ferguson  normal               10
# Adam_Schlegel   normal                5
#                 major                 2
# ChrisAustin     normal                2
#                 minor                 1
# ...                                 ...
# veronika_irvine normal                1
# wassim.melhem   normal                2
#                 blocker               1
#                 major                 1
# zhiyongl        normal                1
#
# [593 rows x 1 columns]

# %%
critical_bugs_df = renamed_bugs_df.loc[renamed_bugs_df["Severity"]=="critical",:]
critical_bugs_df.head()
# Out:
#     Bug ID   Product Component Assignee    Status Resolution  \
# 12   30991       JDT        UI  aeschli  VERIFIED      FIXED
# 14   43518       JDT        UI  aeschli  VERIFIED      FIXED
# 26   16283  Platform   Compare  akiezun  VERIFIED      FIXED
# 28   18079       JDT        UI  akiezun  VERIFIED      FIXED
# 30   18581       JDT        UI  akiezun  VERIFIED      FIXED
#
#                                               Summary          Changed  \
# 12                     NPE in New Java Project Wizard  2/24/2003 10:28
# 14  Stepping through session bean is very slow in ...  10/17/2003 5:27
# 26          Add from Local History items are unsorted    6/3/2002 6:38
# 28  We must guard our Action against a Java editor...    6/3/2002 6:32
# 30  Single element view - markers from other eleme...    6/3/2002 8:08
#
#     Assignee Real Name Classification  ... Number of Comments  \
# 12  Martin Aeschlimann        Eclipse  ...                  5
# 14  Martin Aeschlimann        Eclipse  ...                 14
# 26         Adam Kiezun        Eclipse  ...                  8
# 28         Adam Kiezun        Eclipse  ...                  5
# 30         Adam Kiezun        Eclipse  ...                  9
#
#              Opened            OS Priority      Reporter Reporter Real Name  \
# 12   2/5/2003 12:51    Windows XP       P1     csmclaren      Chris McLaren
# 14  9/23/2003 11:52  Windows 2000       P1      stevenyj         Steven Jin
# 26  5/17/2002 13:29  Windows 2000       P1    nick_edgar         Nick Edgar
# 28  5/28/2002 13:13  Windows 2000       P1  dirk_baeumer       Dirk Baeumer
# 30    6/1/2002 8:01  Windows 2000       P1   erich_gamma        Erich Gamma
#
#     Severity Target Milestone Version Votes
# 12  critical          2.1 RC1     2.1     0
# 14  critical            2.1.2   2.1.1     0
# 26  critical           2.0 F2       2     0
# 28  critical           2.0 F2       2     0
# 30  critical           2.0 F2       2     0
#
# [5 rows x 21 columns]

# %%
grouped_critical = critical_bugs_df.groupby("Assignee")
critical_count = grouped_critical["Severity"].count()
critical_count
# Out:
# Assignee
# Claude_Knaus            3
# Darin_Swanson          33
# Kevin_McGuire           1
# Michael_Rennie          5
# Olivier_Thomann         5
#                        ..
# sxenos                  7
# szymon.ptaszkiewicz     1
# till_bay                3
# valentam                2
# veronika_irvine         1
# Name: Severity, Length: 89, dtype: int64

# %%
total_critical_bugs = len(critical_bugs_df)
total_critical_bugs
# Out:
# 459

# %%
critical_df = pd.DataFrame(critical_count)
critical_df.head()
# Out:
#                  Severity
# Assignee
# Claude_Knaus            3
# Darin_Swanson          33
# Kevin_McGuire           1
# Michael_Rennie          5
# Olivier_Thomann         5

# %%
critical_df = critical_df.rename(columns={"Severity":"Critical Bug Count"})
critical_df.head()
# Out:
#                  Critical Bug Count
# Assignee
# Claude_Knaus                      3
# Darin_Swanson                    33
# Kevin_McGuire                     1
# Michael_Rennie                    5
# Olivier_Thomann                   5

# %%
critical_df["% of Critical Cases Done"] = critical_df["Critical Bug Count"]/total_critical_bugs*100
critical_df.head()
# Out:
#                  Critical Bug Count  % of Critical Cases Done
# Assignee
# Claude_Knaus                      3                  0.653595
# Darin_Swanson                    33                  7.189542
# Kevin_McGuire                     1                  0.217865
# Michael_Rennie                    5                  1.089325
# Olivier_Thomann                   5                  1.089325

# %%
critical_df["% of Critical Cases Done"] = critical_df["% of Critical Cases Done"].map("{:.2f}%".format)
critical_df.head()
# Out:
#                  Critical Bug Count % of Critical Cases Done
# Assignee
# Claude_Knaus                      3                    0.65%
# Darin_Swanson                    33                    7.19%
# Kevin_McGuire                     1                    0.22%
# Michael_Rennie                    5                    1.09%
# Olivier_Thomann                   5                    1.09%

# %%
critical_df.sort_values("Critical Bug Count")
# Out:
#                 Critical Bug Count % of Critical Cases Done
# Assignee
# emoffatt                         1                    0.22%
# dean.t.roberts                   1                    0.22%
# debbie_wilson                    1                    0.22%
# djo                              1                    0.22%
# eclipse.felipe                   1                    0.22%
# ...                            ...                      ...
# eclipse                         23                    5.01%
# Tod_Creasey                     25                    5.45%
# Darin_Swanson                   33                    7.19%
# daniel_megert                   37                    8.06%
# darin.eclipse                   48                   10.46%
#
# [89 rows x 2 columns]
